# %%
# MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# Facciamo un primo esempio molto banale. Costruiamo una retta

# %%
# Si ricordi che la retta ha funzione y = mx + q

# %%
# Creiamo quindi il vettore x e, da esso, ricaviamo il vettore y

# %%
x = np.random.seed(10)
x = np.random.randint(10,100,5)
x
# Out:
# array([19, 25, 74, 38, 99])

# %%
y = 3*x+9
y
# Out:
# array([207, 261, 702, 378, 927])

# %%
plt.plot(x,y)

# %%
# matplotlib.lines.Line2D è la tipologia dell'array del nostro risultato, 0x2153d5e4200 è lo spazio di memoria occupato

# %%
# Se non vogliamo vedere la tipologia e lo spazio di memoria occupato, possiamo aggiungere il comando
# plot.show().  Si noti che questo comando è obbligatorio se vogliamo vedere un grafico 
# su un IDE diverso da Jupiter, quindi per esempio spider, pycharm etc.

# %%
plt.plot(x,y)
plt.show()

# %%
# Inzializzazione del canvas
