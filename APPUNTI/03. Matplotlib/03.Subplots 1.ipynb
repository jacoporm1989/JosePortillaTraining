# %%
# PLT.SUBPLOTS: PARTE 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# plt.subplot crea in automatico un set di assi. Vediamo qualche esempio.

# %%
# Per prima cosa creiamo due funzioni, come fatto finora. Ricordiamo
# che il primo esempio è una retta, il secondo una curva esponenziale.
# Questo ci serve per rappresentare

# %%
np.random.seed(20)
x = np.random.randint(3,10,5)

# %%
y = 4*x+7

# %%
x
# Out:
# array([6, 5, 7, 5, 4])

# %%
y
# Out:
# array([31, 27, 35, 27, 23])

# %%
np.random.seed(20)
a = np.random.randint(3,10,5)

# %%
b = a**3

# %%
a
# Out:
# array([6, 5, 7, 5, 4])

# %%
b
# Out:
# array([216, 125, 343, 125,  64], dtype=int32)

# %%
# La funzione si scrive nel seguente modo:
# fig, axes = plt.subplots().
# Di default, il numero di righe e il numero di colonne è settato a 1.
# In questo modo, gli assi prendono tutto il canvas.
# Infatti:

# %%
fig,axes= plt.subplots()

# %%
# Il che equivale a scrivere:

# %%
fig,axes= plt.subplots(1,1)

# %%
# Si ricordi che il primo argomento della funzione corrisponde al numero di righe, mentre
# il secondo corrisponde al numero di colonne.

# %%
# Proviamo quindi a modificare il numero di righe e il numero di colonne:

# %%
fig,axes= plt.subplots(2,1)

# %%
fig,axes= plt.subplots(5,2)

# %%
fig,axes= plt.subplots(2,4)

# %%
# E via dicendo

# %%
# Ma cosa è axis? E' un numpy array!!! Prendiamo un
# esempio a caso:

# %%
fig,axes= plt.subplots(5,4)

# %%
# Stampiamo axes
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
# Il numero di liste presenti in axes è il numero di grafici
# lungo l'asse delle righe, mentre il numero di elementi di
# axes è il numero di grafici lungo le colonne

# %%
# All'interno dei grafici possiamo mostrare le nostre funzioni. Nei nostri esempi
# Abbiamo una funzione esponenziale ed una lineare. Partiamo dalla situazione più semplice

# %%
fig,axes= plt.subplots()

# %%
# Se volessimo inserire la nostra funzione esponenziale nel canvas mostrato:

# %%
fig,axes= plt.subplots()
axes.plot(a,b)

# %%
type(axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
# La funzione fa schifo, però abbiamo reso l'idea.

# %%
# Vediamo ora la seconda situazione

# %%
fig,axes= plt.subplots(2,1) 
axes[0].plot(a,b)
axes[1].plot(x,y)

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
# Proviamo un caso più complesso:

# %%
fig,axes=plt.subplots(2,5)
axes[1][2].plot(x,y)
axes[0][0].plot(x,y)

# %%
# Il meccanismo dovrebbe essere chiaro!
